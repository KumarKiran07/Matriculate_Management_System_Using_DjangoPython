# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
temp = pd.read_csv('insurance.csv',usecols=['age','bmi'])
temp
# Out:
#      age     bmi
# 0     19  27.900
# 1     18  33.770
# 2     28  33.000
# 3     33  22.705
# 4     32  28.880
# ..   ...     ...
# 494   21  25.700
# 495   20  27.930
# 496   31  23.600
# 497   45  28.700
# 498   44  23.980
#
# [499 rows x 2 columns]

# %%
plt.xlabel('age')
plt.ylabel('bmi')
plt.scatter(temp.age, temp.bmi, color='red', marker='*')

# %%
new_temp = temp.drop('bmi', axis='columns')
new_temp
# Out:
#      age
# 0     19
# 1     18
# 2     28
# 3     33
# 4     32
# ..   ...
# 494   21
# 495   20
# 496   31
# 497   45
# 498   44
#
# [499 rows x 1 columns]

# %%
model = linear_model.LinearRegression()
model.fit(new_temp,temp.bmi)
# Out:
# LinearRegression()

# %%
model.predict([[120]])
# Out:
# C:\Python311\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([35.04783967])
