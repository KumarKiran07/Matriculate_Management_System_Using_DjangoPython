# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5,6,7]
y= [12,15,8,6,3,19,7]

# %%
plt.plot(x,y)

# %%
plt.xlabel('axis')
plt.ylabel('Before 20 year')

plt.title('Graph Representation')
plt.plot(x,y)
