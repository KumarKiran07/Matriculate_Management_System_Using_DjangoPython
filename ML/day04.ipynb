# %%
import pandas as pd

# %%
graph = pd.read_csv('graph_data.csv')

# %%
graph
# Out:
#    product  profit  loss
# 0       12      10    34
# 1       23      20    76
# 2       34      30    42
# 3       45      35    98
# 4       56      70    45
# 5       67      34    90

# %%
graph.plot(x="product", y=['profit','loss'])
# Out:
# <Axes: xlabel='product'>

# %%
ax = graph.plot.area()

# %%
ax = graph.plot.bar(x='product', y=['loss','profit'])

# %%
ax = graph.plot.box()

# %%
graph.plot.line()
# Out:
# <Axes: >

# %%
graph.plot.line(subplots = True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
graph.plot.scatter(x="product", y='profit')
# Out:
# <Axes: xlabel='product', ylabel='profit'>

# %%
ax = graph.plot.pie(y ='loss', figsize=(5,5))

# %%
ax = graph.plot.pie(subplots = True, figsize=(8,8))
